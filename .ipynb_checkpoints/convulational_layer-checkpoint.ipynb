# %%
import numpy as np
import random
import math
import time
import scipy
from scipy import ndimage, misc
import matplotlib.pyplot as plt

# %%
im = plt.imread('banana.jpg')
print(im.shape, type(im))

#grab red portion of the image
im_red = im.copy()
im_red[:, :, 0] = 0
im_red[:, :, 1] = 0

#turn the rgb image into a gray scale image.
im_gray = np.dot(im[...,:3], [0.299, 0.587, 0.114])


plt.imshow(im_gray)
plt.show()
# Out:
# (160, 240, 3) <class 'numpy.ndarray'>

# %%
def init_weights(depth, size):
    weights = []
    for i in range(depth):
        weights.append([np.random.randn(size, size)])
    return weights;

# %%
def conv_layer(image, stride, filter_size, weights):
    padding = 0
    depth = 3
    
    biases = np.random.rand(depth, 1)
    
    output_x = int((image.shape[0] - filter_size + 2*padding)/stride + 1)
    output_y = int((image.shape[1] - filter_size + 2*padding)/stride + 1)
    
    activation = []
    for i in range(depth):
        activation.append(np.empty((output_x * output_y)))
        
    for i in range(depth):
        slide = 0
        row = 0
        for j in range(len(activation[i])):
            activation[i][j] = np.sum(image[row:filter_size+row, slide:filter_size+slide] + weights[i][0]) + biases[i]
            slide += stride
            if (filter_size + slide)-stride >= image.shape[1]:
                slide = 0
                row += stride
        activation[i] = activation[i].reshape((output_x, output_y))
    return np.asarray(activation)

# %%
def relu_layer(image):
    for i in range(image.shape[0]):
        output = np.maximum(0, image[i])

    return image

# %%
def maxpooling_layer():
# Out:
#   File "<ipython-input-67-574d5ef76d74>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
output = conv_layer(im_gray, 1, 2, init_weights(3, 2))
output = relu_layer(output)
output = conv_layer(output[0], 1, 2, init_weights(3, 2))
output = relu_layer(output)

plt.imshow(output[0])
plt.show()

# %%
x = [[-1, -1],
     [1, 2]]
y = np.maximum(0, x)
print(y)
# Out:
# [[0 0]
#  [1 2]]

# %%
print(output)
# Out:
# [array([[117.72094247, 102.72094247,  93.72094247, ...,  76.22694247,
#          61.86194247,  76.18694247],
#        [ 89.72094247,  80.72094247,  77.72094247, ...,  39.52794247,
#          38.47894247,  49.05994247],
#        [118.72094247, 112.72094247, 111.72094247, ...,  31.87594247,
#          35.34294247,  35.62494247],
#        ...,
#        [182.00294247, 196.69894247, 214.74294247, ..., 131.99894247,
#         140.00994247, 141.02094247],
#        [170.28494247, 196.22594247, 225.74294247, ..., 113.41894247,
#         115.14194247, 129.75094247],
#        [181.61594247, 180.84494247, 199.37294247, ..., 171.13794247,
#         133.57294247, 119.88294247]]), array([[117.60062663, 102.60062663,  93.60062663, ...,  76.10662663,
#          61.74162663,  76.06662663],
#        [ 89.60062663,  80.60062663,  77.60062663, ...,  39.40762663,
#          38.35862663,  48.93962663],
#        [118.60062663, 112.60062663, 111.60062663, ...,  31.75562663,
# ...
